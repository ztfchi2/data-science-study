# %% [markdown]
# ### 데이터프레임
# - df

# %%
import pandas as pd

# %%
df = pd.DataFrame({'A':[10,20,30], # 데이터프레임 생성
                  'B':[30,40,50], 
                  'C':['a','b','c']})

# %%
df
# A,B,C : 컬럼
# 0,1,2 : 인덱스
# 나머지는 값들
# Out:
#     A   B  C
# 0  10  30  a
# 1  20  40  b
# 2  30  50  c

# %%
df['C'] # 열을 기준으로 가져올 수 있다.
# Out:
# 0    a
# 1    b
# 2    c
# Name: C, dtype: object

# %%
df['C'].to_frame()
# Out:
#    C
# 0  a
# 1  b
# 2  c

# %%
df[['C','B']]
# Out:
#    C   B
# 0  a  30
# 1  b  40
# 2  c  50

# %%
sum(df['A']) # 연산이 가능하다.
# Out:
# 60

# %%
sum(df['A'])/3
# Out:
# 20.0

# %% [markdown]
# ### 예시 데이터

# %%
df = pd.read_excel("excel_exam.xlsx") # 엑셀 데이터 불러오기

# %%
df
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
len(df) # 데이터의 개수(길이) 확인
# Out:
# 20

# %%
sum(df["math"])/len(df) # 평균 구하기
# Out:
# 57.45

# %%
df["math"]*5
# Out:
# 0     250
# 1     300
# 2     225
# 3     150
# 4     125
# 5     250
# 6     400
# 7     450
# 8     100
# 9     250
# 10    325
# 11    225
# 12    230
# 13    240
# 14    375
# 15    290
# 16    325
# 17    400
# 18    445
# 19    390
# Name: math, dtype: int64

# %% [markdown]
# ### 데이터에 대한 기초 이해
# - head() : 데이터프레임 앞의 값 출력
# - tail() : 데이터프레임 뒤의 값 출력
# - shape : 행, 열
# - info() : 변수 속성
# - describe() : 요약통계량 출력

# %%
df_1 = pd.read_csv("mpg.csv")

# %%
df_1
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df_1.head() # 앞 5개의 값을 볼 수 있음
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df_1.tail() # 뒤 5개의 값을 볼 수 있음
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
df_1.shape # 행 열
# Out:
# (234, 11)

# %%
df_1
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df_1.describe() # 요약 통계
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# - count 빈도, 값의 개수
# - mean 평균
# - std 표준편차
# - min 최솟값
# - 25% 1사분위수
# - 50% 2사분위수(중앙값)
# - 75% 3사분위수
# - max 최댓값

# %%
df_1
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  test
# 0    compact     0
# 1    compact     1
# 2    compact     1
# 3    compact     1
# ...

# %%
# 숫자형 데이터를 제외한 범주형, 문자열 데이터는 (object)

df_1["manufacturer"].value_counts()
# 카운팅이 들어가야 된다.
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# hyundai       14
# subaru        14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# land rover     4
# mercury        4
# lincoln        3
# Name: manufacturer, dtype: int64

# %% [markdown]
# ### 데이터프레임 변수명 바꾸기

# %%
df_new = df.rename(columns={"nclass":"nc"}) # 변수명을 바꾸는 법
                                            # 기존변수:바꿀변수

# %%
df_new
# Out:
#     id  nc  math  english  science
# 0    1   1    50       98       50
# 1    2   1    60       97       60
# 2    3   1    45       86       78
# 3    4   1    30       98       58
# 4    5   2    25       80       65
# 5    6   2    50       89       98
# 6    7   2    80       90       45
# 7    8   2    90       78       25
# 8    9   3    20       98       15
# 9   10   3    50       98       45
# 10  11   3    65       65       65
# 11  12   3    45       85       32
# 12  13   4    46       98       65
# 13  14   4    48       87       12
# 14  15   4    75       56       78
# 15  16   4    58       98       65
# 16  17   5    65       68       98
# 17  18   5    80       78       90
# 18  19   5    89       68       87
# 19  20   5    78       83       58

# %%
df_cp = df.copy() # 데이터프레임을 카피하는 방법

# %%
df_cp
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ### 파생변수 만들기!

# %%
# 수학, 영어, 과학의 합을 구하자!
df["tot_sum"] = df["math"] + df["english"] + df["science"]

# %%
df["tot_sum"]/3
# Out:
# 0     66.000000
# 1     72.333333
# 2     69.666667
# 3     62.000000
# 4     56.666667
# 5     79.000000
# 6     71.666667
# 7     64.333333
# 8     44.333333
# 9     64.333333
# 10    65.000000
# 11    54.000000
# 12    69.666667
# 13    49.000000
# 14    69.666667
# 15    73.666667
# 16    77.000000
# 17    82.666667
# 18    81.333333
# 19    73.000000
# Name: tot_sum, dtype: float64

# %%
df["math"].mean() # 수학에 대한 평균
# Out:
# 57.45

# %%
df["math"].max() # 수학의 최댓값
# Out:
# 90

# %%
df["math"]
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
df["tot_mean"] = df["tot_sum"]/3

# %%
df
# Out:
#     id  nclass  math  english  science  tot_sum   tot_mean
# 0    1       1    50       98       50      198  66.000000
# 1    2       1    60       97       60      217  72.333333
# 2    3       1    45       86       78      209  69.666667
# 3    4       1    30       98       58      186  62.000000
# 4    5       2    25       80       65      170  56.666667
# 5    6       2    50       89       98      237  79.000000
# 6    7       2    80       90       45      215  71.666667
# 7    8       2    90       78       25      193  64.333333
# 8    9       3    20       98       15      133  44.333333
# 9   10       3    50       98       45      193  64.333333
# 10  11       3    65       65       65      195  65.000000
# 11  12       3    45       85       32      162  54.000000
# 12  13       4    46       98       65      209  69.666667
# 13  14       4    48       87       12      147  49.000000
# 14  15       4    75       56       78      209  69.666667
# ...

# %%
df["math"].plot.hist() # 시각화!
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_1.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
df["math"].describe()
# Out:
# count    20.000000
# mean     57.450000
# std      20.299015
# min      20.000000
# 25%      45.750000
# 50%      54.000000
# 75%      75.750000
# max      90.000000
# Name: math, dtype: float64

# %%
df.math.sum() # 안으로 들어갈수록 문법이 적용되는 것
# Out:
# 1149

# %%
df_1.manufacturer.value_counts().max()
# Out:
# 37

# %%
df_1.manufacturer.value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# hyundai       14
# subaru        14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# land rover     4
# mercury        4
# lincoln        3
# Name: manufacturer, dtype: int64

# %% [markdown]
# ### 넘파이를 이용해서 데이터 값을 변경할 수 있다.

# %%
import numpy as np

# %%
df_1["test"] = np.where(df_1["cty"]>=20,1,0)
# np.where(조건,참일 때 결과,거짓일 때 결과)

# %%
df_1
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  test
# 0    compact     0
# 1    compact     1
# 2    compact     1
# 3    compact     1
# ...
